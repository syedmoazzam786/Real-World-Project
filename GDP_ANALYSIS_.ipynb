# %% [markdown]
# <a href="https://colab.research.google.com/github/syedmoazzam786/Real-World-Project/blob/main/GDP_ANALYSIS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/dataset/gdp.csv")

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %% [markdown]
# ##1) How many unique Countries Data we're having in the dataset?

# %%
df['Country Name'].nunique()
# Out:
# 256

# %%
df.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# Year            0
# Value           0
# dtype: int64

# %% [markdown]
# ## check description of each column

# %%
df['Country Name'].describe()
# Out:
# count                    11507
# unique                     256
# top       Hong Kong SAR, China
# freq                        57
# Name: Country Name, dtype: object

# %%
df['Country Code'].describe()
# Out:
# count     11507
# unique      256
# top         HKG
# freq         57
# Name: Country Code, dtype: object

# %%
df['Year'].describe()
# Out:
# count    11507.000000
# mean      1991.265230
# std         15.886648
# min       1960.000000
# 25%       1978.000000
# 50%       1993.000000
# 75%       2005.000000
# max       2016.000000
# Name: Year, dtype: float64

# %%
df['Year'].min()
# Out:
# 1960

# %%
df['Year'].max()
# Out:
# 2016

# %% [markdown]
# ## analysing arab world

# %%
df[df['Country Name'] == 'Arab World']
# Out:
#    Country Name Country Code  Year         Value
# 0    Arab World          ARB  1968  2.576068e+10
# 1    Arab World          ARB  1969  2.843420e+10
# 2    Arab World          ARB  1970  3.138550e+10
# 3    Arab World          ARB  1971  3.642691e+10
# 4    Arab World          ARB  1972  4.331606e+10
# 5    Arab World          ARB  1973  5.501839e+10
# 6    Arab World          ARB  1974  1.051458e+11
# 7    Arab World          ARB  1975  1.163370e+11
# 8    Arab World          ARB  1976  1.448462e+11
# 9    Arab World          ARB  1977  1.673083e+11
# 10   Arab World          ARB  1978  1.835555e+11
# 11   Arab World          ARB  1979  2.486462e+11
# 12   Arab World          ARB  1980  3.381775e+11
# 13   Arab World          ARB  1981  3.485928e+11
# 14   Arab World          ARB  1982  3.243288e+11
# 15   Arab World          ARB  1983  3.039625e+11
# 16   Arab World          ARB  1984  3.079408e+11
# 17   Arab World          ARB  1985  3.038936e+11
# ...

# %%
df_pr = df[df['Country Name'] == 'Arab World']

# %%
df_pr.plot(kind = 'line', x = 'Year', y = 'Value',figsize = (15,6),grid = True,legend = False)
 # Change 'Line' to 'line' for a line plot
# Out:
# <Axes: xlabel='Year'>

# %%
df_pr.plot(kind = 'line', x = 'Year', y = 'Value',figsize = (15,6),grid = True,legend = False ,xlabel = 'Year', ylabel = 'GDP')
# Out:
# <Axes: xlabel='Year', ylabel='GDP'>

# %%
df_pr = df[df['Country Name'] == 'India']

# %%
df_pr.plot(kind = 'line', x = 'Year', y = 'Value',figsize = (15,6),grid = True,legend = False ,xlabel = 'Year', ylabel = 'GDP')
# Out:
# <Axes: xlabel='Year', ylabel='GDP'>

# %%
df_pr
# Out:
#      Country Name Country Code  Year         Value
# 6074        India          IND  1960  3.653593e+10
# 6075        India          IND  1961  3.870910e+10
# 6076        India          IND  1962  4.159907e+10
# 6077        India          IND  1963  4.777600e+10
# 6078        India          IND  1964  5.572687e+10
# 6079        India          IND  1965  5.876042e+10
# 6080        India          IND  1966  4.525364e+10
# 6081        India          IND  1967  4.946617e+10
# 6082        India          IND  1968  5.237732e+10
# 6083        India          IND  1969  5.766833e+10
# 6084        India          IND  1970  6.158980e+10
# 6085        India          IND  1971  6.645256e+10
# 6086        India          IND  1972  7.050991e+10
# 6087        India          IND  1973  8.437454e+10
# 6088        India          IND  1974  9.819828e+10
# 6089        India          IND  1975  9.715922e+10
# 6090        India          IND  1976  1.013470e+11
# ...

# %% [markdown]
# ##How many years of Data we're having for India

# %%
unique_years = df_pr['Year'].nunique()

# %%
unique_years
# Out:
# 57

# %% [markdown]
# ##Whats the world GDP in 1969?

# %%
gdp_1969 = df[df['Year'] == 1969]

# %%
world_gdp_1969 = gdp_1969['Value'].sum()

# %%
world_gdp_1969
# Out:
# 19577201579296.54

# %% [markdown]
# Whats the % of GDP growth of India in Year 1994 (*as compare to 1993)?

# %%
india_gdp_1993 = df[(df['Country Name'] == 'India') & (df['Year'] == 1993)]['Value'].values[0]
india_gdp_1994 = df[(df['Country Name'] == 'India') & (df['Year'] == 1994)]['Value'].values[0]

# %%
gdp_growth_percentage = ((india_gdp_1994 - india_gdp_1993) / india_gdp_1993) * 100

# %%
gdp_growth_percentage
# Out:
# 17.178748210146075

# %% [markdown]
# ##) Find GDP Growth of India from 1960 - 2016

# %%
india_gdp_data = df[(df['Country Name'] == 'India') & (df['Year'].between(1960, 2016))]

# %%
india_gdp_data = india_gdp_data.sort_values(by='Year')

# %%
india_gdp_data['GDP Growth (%)'] = india_gdp_data['Value'].pct_change() * 100

# %%
print(india_gdp_data['Year'])
# Out:
# 6074    1960
# 6075    1961
# 6076    1962
# 6077    1963
# 6078    1964
# 6079    1965
# 6080    1966
# 6081    1967
# 6082    1968
# 6083    1969
# 6084    1970
# 6085    1971
# 6086    1972
# 6087    1973
# 6088    1974
# 6089    1975
# 6090    1976
# 6091    1977
# 6092    1978
# 6093    1979
# 6094    1980
# 6095    1981
# 6096    1982
# 6097    1983
# 6098    1984
# 6099    1985
# 6100    1986
# 6101    1987
# 6102    1988
# 6103    1989
# 6104    1990
# 6105    1991
# 6106    1992
# 6107    1993
# 6108    1994
# 6109    1995
# 6110    1996
# 6111    1997
# 6112    1998
# 6113    1999
# 6114    2000
# 6115    2001
# 6116    2002
# 6117    2003
# 6118    2004
# 6119    2005
# 6120    2006
# 6121    2007
# 6122    2008
# 6123    2009
# 6124    2010
# 6125    2011
# 6126    2012
# 6127    2013
# 6128    2014
# 6129    2015
# 6130    2016
# Name: Year, dtype: int64

# %% [markdown]
# ##  Create a new columns named as GDP which shows the GDP growth of each country for that year

# %%
# Sort the data by Country and Year to ensure correct calculation order
df = df.sort_values(by=['Country Name', 'Year'])

# Calculate the year-over-year GDP growth percentage for each country
df['GDP Growth'] = df.groupby('Country Name')['Value'].pct_change() * 100

# Display the first few rows to check the new column
print(df.head())
# Out:
#      Country Name Country Code  Year         Value  GDP Growth
# 2306  Afghanistan          AFG  1960  5.377778e+08         NaN
# 2307  Afghanistan          AFG  1961  5.488889e+08    2.066111
# 2308  Afghanistan          AFG  1962  5.466667e+08   -0.404857
# 2309  Afghanistan          AFG  1963  7.511112e+08   37.398386
# 2310  Afghanistan          AFG  1964  8.000000e+08    6.508870

# %% [markdown]
# .
#
# ##Create a graph of GDP Growth of India from 1960 - 2016

# %%
# Import the matplotlib.pyplot module
import matplotlib.pyplot as plt

# Plot the GDP growth
plt.figure(figsize=(10, 6))
plt.plot(india_gdp_data['Year'], india_gdp_data['GDP Growth (%)'], marker='o', linestyle='-', color='b')

# Adding title and labels
plt.title('GDP Growth of India (1960-2016)')
plt.xlabel('Year')
plt.ylabel('GDP Growth (%)')

# Show the grid and plot
plt.grid(True)
plt.show()

# %%
##GDP ANALYSIS GDP GROWTH OF A COUNTRY

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/dataset/gdp.csv")

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %% [markdown]
# ## Analysing Arab world

# %%
df_pr = df[df['Country Name'] == 'Arab World']

# %%
df_pr.plot(kind = 'line', x = 'Year', y = 'Value',figsize = (15,6),grid = True,legend = False ,xlabel = 'Year', ylabel = 'GDP')
# Out:
# <Axes: xlabel='Year', ylabel='GDP'>

# %%
# 1968 - 2576
# 1969 - 2843
#1970 - 3138

# %%
df_pr.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
df_pr['Year']
# Out:
# 0     1968
# 1     1969
# 2     1970
# 3     1971
# 4     1972
# 5     1973
# 6     1974
# 7     1975
# 8     1976
# 9     1977
# 10    1978
# 11    1979
# 12    1980
# 13    1981
# 14    1982
# 15    1983
# 16    1984
# 17    1985
# 18    1986
# 19    1987
# 20    1988
# 21    1989
# 22    1990
# 23    1991
# 24    1992
# 25    1993
# 26    1994
# 27    1995
# 28    1996
# 29    1997
# 30    1998
# 31    1999
# 32    2000
# 33    2001
# 34    2002
# 35    2003
# 36    2004
# 37    2005
# 38    2006
# 39    2007
# 40    2008
# 41    2009
# 42    2010
# 43    2011
# 44    2012
# 45    2013
# 46    2014
# 47    2015
# 48    2016
# Name: Year, dtype: int64

# %%
data =df_pr.values
for i in range (len(data)):
  print(data[i])
# Out:
# ['Arab World' 'ARB' 1968 25760683041.0857]
# ['Arab World' 'ARB' 1969 28434203615.4829]
# ['Arab World' 'ARB' 1970 31385499664.0672]
# ['Arab World' 'ARB' 1971 36426909888.3928]
# ['Arab World' 'ARB' 1972 43316056615.4562]
# ['Arab World' 'ARB' 1973 55018394945.5825]
# ['Arab World' 'ARB' 1974 105145803084.377]
# ['Arab World' 'ARB' 1975 116337021938.341]
# ['Arab World' 'ARB' 1976 144846175400.488]
# ['Arab World' 'ARB' 1977 167308327683.593]
# ['Arab World' 'ARB' 1978 183555544342.189]
# ['Arab World' 'ARB' 1979 248646206367.003]
# ['Arab World' 'ARB' 1980 338177454717.54]
# ['Arab World' 'ARB' 1981 348592795413.116]
# ['Arab World' 'ARB' 1982 324328753765.3]
# ['Arab World' 'ARB' 1983 303962539723.08]
# ['Arab World' 'ARB' 1984 307940771858.542]
# ['Arab World' 'ARB' 1985 303893618415.542]
# ['Arab World' 'ARB' 1986 289029150639.442]
# ['Arab World' 'ARB' 1987 312681678329.933]
# ['Arab World' 'ARB' 1988 307503035642.516]
# ['Arab World' 'ARB' 1989 322325140494.725]
# ...

# %%
data = df_pr.values
for i in range (len(data)):
  print(data[i-1][2],data[i])
# Out:
# 2016 ['Arab World' 'ARB' 1968 25760683041.0857]
# 1968 ['Arab World' 'ARB' 1969 28434203615.4829]
# 1969 ['Arab World' 'ARB' 1970 31385499664.0672]
# 1970 ['Arab World' 'ARB' 1971 36426909888.3928]
# 1971 ['Arab World' 'ARB' 1972 43316056615.4562]
# 1972 ['Arab World' 'ARB' 1973 55018394945.5825]
# 1973 ['Arab World' 'ARB' 1974 105145803084.377]
# 1974 ['Arab World' 'ARB' 1975 116337021938.341]
# 1975 ['Arab World' 'ARB' 1976 144846175400.488]
# 1976 ['Arab World' 'ARB' 1977 167308327683.593]
# 1977 ['Arab World' 'ARB' 1978 183555544342.189]
# 1978 ['Arab World' 'ARB' 1979 248646206367.003]
# 1979 ['Arab World' 'ARB' 1980 338177454717.54]
# 1980 ['Arab World' 'ARB' 1981 348592795413.116]
# 1981 ['Arab World' 'ARB' 1982 324328753765.3]
# 1982 ['Arab World' 'ARB' 1983 303962539723.08]
# 1983 ['Arab World' 'ARB' 1984 307940771858.542]
# 1984 ['Arab World' 'ARB' 1985 303893618415.542]
# 1985 ['Arab World' 'ARB' 1986 289029150639.442]
# 1986 ['Arab World' 'ARB' 1987 312681678329.933]
# ...

# %%
data = df_pr.values
for i in range (len(data)):
  print(data[i-1][3]-data[i][3])
# Out:
# 2478941942527.544
# -2673520574.3971977
# -2951296048.584301
# -5041410224.3256
# -6889146727.0634
# -11702338330.126297
# -50127408138.7945
# -11191218853.964005
# -28509153462.147003
# -22462152283.10498
# -16247216658.596008
# -65090662024.813995
# -89531248350.53699
# -10415340695.57605
# 24264041647.81604
# 20366214042.21997
# -3978232135.461975
# 4047153443.0
# 14864467776.099976
# -23652527690.490967
# 5178642687.416992
# -14822104852.208984
# -124552021240.435
# 7097983869.825989
# -31384337614.43701
# -5350115140.955994
# -11013275646.67102
# -36232992011.18298
# -54471399478.83295
# -35048154705.651
# 21753858454.825928
# -52364076864.95703
# -91135469453.31995
# 11742323935.231934
# -5768899012.160889
# -94058826037.01904
# -140751799080.11707
# -220799209074.54883
# -219451981205.55005
# -233459666169.9402
# -440542462905.85986
# 282296052763.3699
# -313826214835.2998
# -391907826464.32007
# -239684890031.58008
# -98388097392.25977
# -66989799350.33008
# ...

# %%
round(((5501 - 4331) / 4331)*100,2)
# Out:
# 27.01

# %%
data = df_pr.values
gdp_change = [0]
for i in range (len(data)):


  prev = data[i-1][3]
  curr = data[i][3]
  print(data[i][2],round(((curr - prev) / prev)*100,2))
# Out:
# 1968 -98.97
# 1969 10.38
# 1970 10.38
# 1971 16.06
# 1972 18.91
# 1973 27.02
# 1974 91.11
# 1975 10.64
# 1976 24.51
# 1977 15.51
# 1978 9.71
# 1979 35.46
# 1980 36.01
# 1981 3.08
# 1982 -6.96
# 1983 -6.28
# 1984 1.31
# 1985 -1.31
# 1986 -4.89
# 1987 8.18
# 1988 -1.66
# 1989 4.82
# 1990 38.64
# 1991 -1.59
# 1992 7.14
# 1993 1.14
# 1994 2.31
# 1995 7.43
# 1996 10.4
# 1997 6.06
# 1998 -3.55
# 1999 8.85
# 2000 14.15
# 2001 -1.6
# 2002 0.8
# 2003 12.9
# 2004 17.1
# 2005 22.91
# 2006 18.52
# 2007 16.63
# 2008 26.9
# 2009 -13.58
# 2010 17.48
# 2011 18.58
# 2012 9.58
# 2013 3.59
# 2014 2.36
# 2015 -11.81
# 2016 -2.29

# %%
data = df_pr.values

gdp_change = [0]

for i in range (1,len(data)):
  prev = data[i-1][3]
  curr = data[i][3]
  gdp_change.append(round(((curr - prev) / prev)*100,2))

# %%
gdp_change
# Out:
# [0,
#  10.38,
#  10.38,
#  16.06,
#  18.91,
#  27.02,
#  91.11,
#  10.64,
#  24.51,
#  15.51,
#  9.71,
#  35.46,
#  36.01,
#  3.08,
#  -6.96,
#  -6.28,
#  1.31,
#  -1.31,
#  -4.89,
#  8.18,
#  -1.66,
#  4.82,
#  38.64,
#  -1.59,
#  7.14,
#  1.14,
#  2.31,
#  7.43,
#  10.4,
#  6.06,
#  -3.55,
#  8.85,
#  14.15,
#  -1.6,
#  0.8,
#  12.9,
#  17.1,
#  22.91,
#  18.52,
#  16.63,
#  26.9,
#  -13.58,
#  17.48,
#  18.58,
#  9.58,
#  3.59,
#  2.36,
#  -11.81,
#  -2.29]

# %%
df_pr.assign(GDP = gdp_change)
# Out:
#    Country Name Country Code  Year         Value    GDP
# 0    Arab World          ARB  1968  2.576068e+10   0.00
# 1    Arab World          ARB  1969  2.843420e+10  10.38
# 2    Arab World          ARB  1970  3.138550e+10  10.38
# 3    Arab World          ARB  1971  3.642691e+10  16.06
# 4    Arab World          ARB  1972  4.331606e+10  18.91
# 5    Arab World          ARB  1973  5.501839e+10  27.02
# 6    Arab World          ARB  1974  1.051458e+11  91.11
# 7    Arab World          ARB  1975  1.163370e+11  10.64
# 8    Arab World          ARB  1976  1.448462e+11  24.51
# 9    Arab World          ARB  1977  1.673083e+11  15.51
# 10   Arab World          ARB  1978  1.835555e+11   9.71
# 11   Arab World          ARB  1979  2.486462e+11  35.46
# 12   Arab World          ARB  1980  3.381775e+11  36.01
# 13   Arab World          ARB  1981  3.485928e+11   3.08
# 14   Arab World          ARB  1982  3.243288e+11  -6.96
# 15   Arab World          ARB  1983  3.039625e+11  -6.28
# ...

# %%
##  GDP growth on whole dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/dataset/gdp.csv")

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %% [markdown]
# ## Finding GDP Growth of a country

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/dataset/gdp.csv")

df_pr =df[df['Country Name']=='Arab World']

data = df_pr.values

gdp_change = [0]

for i in range (1,len(data)):
  prev = data[i-1][3]
  curr = data[i][3]

  # The following two lines were not indented properly and were not being executed within the loop
  gdp_change.append(round(((curr - prev) / prev)*100,2))

df_pr = df_pr.assign(GDP = gdp_change) # Now gdp_change will have the same number of values as df_pr

# %% [markdown]
# ## Finding GDP GRowth of every country

# %%
final_data = []

# %%
for country_name in df['Country Name'].unique():
  df_pr = df[df['Country Name'] == country_name]
  data = df_pr.values
  gdp_change = [0]

  for i in range (1,len(data)):
    prev = data[i-1][3]
    curr = data[i][3]
    gdp_change.append(round(((curr - prev) / prev)*100,2))

  # The following line was indented incorrectly, causing the error
  df_pr = df_pr.assign(GDP = gdp_change)
  final_data.append(df_pr)

# %%
df = pd.concat(final_data)

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value    GDP
# 0   Arab World          ARB  1968  2.576068e+10   0.00
# 1   Arab World          ARB  1969  2.843420e+10  10.38
# 2   Arab World          ARB  1970  3.138550e+10  10.38
# 3   Arab World          ARB  1971  3.642691e+10  16.06
# 4   Arab World          ARB  1972  4.331606e+10  18.91

# %%
df.groupby('Country Name').max()['Value'].sort_values(ascending = False).head(50)
# Out:
# Country Name
# World                                                   7.904923e+13
# High income                                             5.036240e+13
# OECD members                                            4.937008e+13
# Post-demographic dividend                               4.673504e+13
# IDA & IBRD total                                        2.948247e+13
# Low & middle income                                     2.870476e+13
# Middle income                                           2.829277e+13
# IBRD only                                               2.739661e+13
# Europe & Central Asia                                   2.365470e+13
# East Asia & Pacific                                     2.248043e+13
# Upper middle income                                     2.221220e+13
# North America                                           2.016030e+13
# Late-demographic dividend                               1.970310e+13
# ...

# %%
## plotting graph using plotly

# %%
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

df = pd.read_csv("/content/drive/MyDrive/dataset/gdp.csv")

df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
final_data = []

for country_name in df['Country Name'].unique():
  df_pr = df[df['Country Name'] == country_name]
  data = df_pr.values
  gdp_change = [0]

  for i in range (1,len(data)):
    prev = data[i-1][3]
    curr = data[i][3]

    gdp_change.append(round(((curr - prev) / prev)*100,2))

  # Assign gdp_change after the inner loop completes
  df_pr = df_pr.assign(GDP = gdp_change)
  final_data.append(df_pr) # Append df_pr to final_data outside the inner loop

df = pd.concat(final_data,axis = 0) # Concatenate all dataframes after the outer loop

# %%
df.head()
# Out:
#   Country Name Country Code  Year         Value    GDP
# 0   Arab World          ARB  1968  2.576068e+10   0.00
# 1   Arab World          ARB  1969  2.843420e+10  10.38
# 2   Arab World          ARB  1970  3.138550e+10  10.38
# 3   Arab World          ARB  1971  3.642691e+10  16.06
# 4   Arab World          ARB  1972  4.331606e+10  18.91

# %%
df_pr = df[df['Country Name'] == 'World']

fig = px.line(df_pr,x = 'Year',y = 'Value',title = 'World GDP Analysis')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pyo.plot(fig,filename = 'world_gdp.html')
# Out:
# 'world_gdp.html'

# %%
df_pr = df[df['Country Name'] == 'India']

fig = px.line(df_pr,x = 'Year',y = 'Value',title = 'India GDP Analysis')
pyo.plot(fig,filename = 'india.html')
# Out:
# 'india.html'

# %%
df_pr = df[df['Country Name'] == 'India']

fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'Indian GDP Analysis', range_y = [0, 4000000000000])

fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## plotting graps in bulk

# %%
import os
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

# Removed extra double quote at the beginning of the file path
df = pd.read_csv('/content/drive/MyDrive/dataset/gdp.csv')

final_data = []

for country_name in df['Country Name'].unique():
    df_pr = df[df['Country Name'] == country_name]
    data = df_pr.values
    gdp_change = [0]

    for i in range(1, len(data)):
        prev = data[i - 1][3]
        curr = data[i][3]
        gdp_change.append(round(((curr - prev) / prev) * 100, 2))

    df_pr = df_pr.assign(GDP=gdp_change)
    final_data.append(df_pr)

df = pd.concat(final_data, axis=0)

df.head()
# Out:
#   Country Name Country Code  Year         Value    GDP
# 0   Arab World          ARB  1968  2.576068e+10   0.00
# 1   Arab World          ARB  1969  2.843420e+10  10.38
# 2   Arab World          ARB  1970  3.138550e+10  10.38
# 3   Arab World          ARB  1971  3.642691e+10  16.06
# 4   Arab World          ARB  1972  4.331606e+10  18.91

# %% [markdown]
# ## GDP of each country

# %%
import os
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

# Check if the directory exists before trying to create it
if not os.path.exists('GDP Individual'):
    os.mkdir('GDP Individual')

for country_name in df['Country Name'].unique():

    df_pr = df[df['Country Name'] == country_name]
    fig = px.line(df_pr, x = 'Year', y = 'Value', title = country_name + ' GDP Analysis')
    pyo.plot(fig, filename = 'GDP Individual/' + country_name + '.html', auto_open = False)

# %% [markdown]
# ## GDP of Each Country WRT 80T

# %%
os.mkdir('GDP Individual WRT World')

for country_name in df['Country Name'].unique():

    df_pr = df[df['Country Name'] == country_name]
    fig = px.line(df_pr, x = 'Year', y = 'Value', title = country_name + ' GDP Analysis', range_y = [0,80000000000000])
    pyo.plot(fig, filename = 'GDP Individual WRT World/' + country_name + '.html', auto_open = False)

# %%
## compare gdp across countries

# %%
import os
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

df = pd.read_csv("/content/drive/MyDrive/dataset/gdp.csv")

final_data = []

for country_name in df['Country Name'].unique():
    df_pr = df[df['Country Name'] == country_name]
    data = df_pr.values
    gdp_change = [0]

    for i in range(1,len(data)):
        prev = data[i-1][3]
        cur = data[i][3]
        gdp_change.append(round(((cur - prev) / prev)*100,2))

    df_pr = df_pr.assign(GDP = gdp_change)
    final_data.append(df_pr)

df = pd.concat(final_data, axis = 0)

df.head()
# Out:
#   Country Name Country Code  Year         Value    GDP
# 0   Arab World          ARB  1968  2.576068e+10   0.00
# 1   Arab World          ARB  1969  2.843420e+10  10.38
# 2   Arab World          ARB  1970  3.138550e+10  10.38
# 3   Arab World          ARB  1971  3.642691e+10  16.06
# 4   Arab World          ARB  1972  4.331606e+10  18.91

# %% [markdown]
# ## GDP of all countries

# %%
fig = px.line(df, x = 'Year', y = 'Value', title = 'GDP Analysis of All Countries', color = 'Country Name')

pyo.plot(fig, filename = 'Countries GDP.html')
# Out:
# 'Countries GDP.html'

# %% [markdown]
# ##GDP Comparison between India & China

# %%
c1 = df[df['Country Name'] == 'China']
c2 = df[df['Country Name'] == 'India']
c2.head()
# Out:
#      Country Name Country Code  Year         Value    GDP
# 6074        India          IND  1960  3.653593e+10   0.00
# 6075        India          IND  1961  3.870910e+10   5.95
# 6076        India          IND  1962  4.159907e+10   7.47
# 6077        India          IND  1963  4.777600e+10  14.85
# 6078        India          IND  1964  5.572687e+10  16.64

# %%
df_pr = pd.concat([c1,c2],axis = 0)
df_pr
# Out:
#      Country Name Country Code  Year         Value    GDP
# 4046        China          CHN  1960  5.971647e+10   0.00
# 4047        China          CHN  1961  5.005687e+10 -16.18
# 4048        China          CHN  1962  4.720936e+10  -5.69
# 4049        China          CHN  1963  5.070680e+10   7.41
# 4050        China          CHN  1964  5.970834e+10  17.75
# ...           ...          ...   ...           ...    ...
# 6126        India          IND  2012  1.827638e+12   0.25
# 6127        India          IND  2013  1.856722e+12   1.59
# 6128        India          IND  2014  2.035393e+12   9.62
# 6129        India          IND  2015  2.089865e+12   2.68
# 6130        India          IND  2016  2.263792e+12   8.32
#
# [114 rows x 5 columns]

# %%
fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'GDP Comparison | India & China', color = 'Country Name')

pyo.plot(fig, filename = 'IND|CHN.html')
# Out:
# 'IND|CHN.html'

# %%
c1 = df[df['Country Name'] == 'China']
c2 = df[df['Country Name'] == 'World']

df_pr = pd.concat([c1,c2],axis = 0)

fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'GDP Comparison | World & China', color = 'Country Name')

pyo.plot(fig, filename = 'WLD|CHN.html')
# Out:
# 'WLD|CHN.html'

# %%
import os
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

df = pd.read_csv("/content/drive/MyDrive/dataset/gdp.csv")

final_data = []

for country_name in df['Country Name'].unique():
    df_pr = df[df['Country Name'] == country_name]
    data = df_pr.values
    gdp_change = [0]

    for i in range(1,len(data)):
        prev = data[i-1][3]
        cur = data[i][3]
        gdp_change.append(round(((cur - prev) / prev)*100,2))

    df_pr = df_pr.assign(GDP = gdp_change)
    final_data.append(df_pr)

df = pd.concat(final_data, axis = 0)

df.head()
# Out:
#   Country Name Country Code  Year         Value    GDP
# 0   Arab World          ARB  1968  2.576068e+10   0.00
# 1   Arab World          ARB  1969  2.843420e+10  10.38
# 2   Arab World          ARB  1970  3.138550e+10  10.38
# 3   Arab World          ARB  1971  3.642691e+10  16.06
# 4   Arab World          ARB  1972  4.331606e+10  18.91

# %% [markdown]
# ##GDP Comparison between Specific Countries

# %%
lst = ['IND','ITA', 'USA', 'CHN']

dfs = []
for i in lst:
    dfs.append(df[df['Country Code'] == i])

    df_pr = pd.concat(dfs, axis = 0)

# %%
fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'GDP Comparison - ' + '|'.join(lst), color = 'Country Name')

pyo.plot(fig, filename = '|'.join(lst) + '.html')
# Out:
# 'IND|ITA|USA|CHN.html'

# %%
def comare_gdp(lst, isOpen):

    dfs = []
    for i in lst:
        dfs.append(df[df['Country Code'] == i])

        df_pr = pd.concat(dfs, axis = 0)

    fig = px.line(df_pr, x = 'Year', y = 'Value', title = 'GDP Comparison - ' + '|'.join(lst),
                  color = 'Country Name')
    pyo.plot(fig, filename = '|'.join(lst) + '.html', auto_open = isOpen)

# %%
comare_gdp(['IND','USA'], False)

# %%
## compare gdp growth across countries

# %%
import os
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

df = pd.read_csv("/content/drive/MyDrive/dataset/gdp.csv")

final_data = []

for country_name in df['Country Name'].unique():
    df_pr = df[df['Country Name'] == country_name]
    data = df_pr.values
    gdp_change = [0]

    for i in range(1,len(data)):
        prev = data[i-1][3]
        cur = data[i][3]
        gdp_change.append(round(((cur - prev) / prev)*100,2))

    df_pr = df_pr.assign(GDP = gdp_change)
    final_data.append(df_pr)

df = pd.concat(final_data, axis = 0)

df.head()
# Out:
#   Country Name Country Code  Year         Value    GDP
# 0   Arab World          ARB  1968  2.576068e+10   0.00
# 1   Arab World          ARB  1969  2.843420e+10  10.38
# 2   Arab World          ARB  1970  3.138550e+10  10.38
# 3   Arab World          ARB  1971  3.642691e+10  16.06
# 4   Arab World          ARB  1972  4.331606e+10  18.91

# %% [markdown]
# ## GDP GROWTH OF SPECIFIC COUNTRIES

# %%
def compare_gdp(lst, isOpen):

    dfs = []
    for i in lst:
        dfs.append(df[df['Country Code'] == i])

        df_pr = pd.concat(dfs, axis = 0)

    fig = px.line(df_pr, x = 'Year', y = 'GDP', title = 'GDP Comparison - ' + '|'.join(lst),
                  color = 'Country Name')
    pyo.plot(fig, filename = '|'.join(lst) + '.html', auto_open = isOpen)

# %%
compare_gdp(['IND','USA','ITA','CHN'], True)

# %% [markdown]
# ## GDP Growth Comparies of All the Countries

# %%
fig = px.line(df, x = 'Year', y = 'GDP', title = 'GDP Comparison', color = 'Country Name')
pyo.plot(fig, filename = 'GDP Growth.html', auto_open = True)
# Out:
# 'GDP Growth.html'

# %% [markdown]
# ##GDP Growth of All Countries Graph Individual

# %%
os.mkdir('GDP Growth Individual')

for country_name in df['Country Code'].unique():

    df_pr = df[df['Country Code'] == country_name]

    fig = px.line(df_pr, x = 'Year', y = 'GDP', title = country_name)
    pyo.plot(fig, filename = 'GDP Growth Individual/' + country_name + '.html', auto_open = False)

# %% [markdown]
# GDP Growth between 1960 - 2016

# %%
dfs = []

for country_name in df['Country Name'].unique():
    df_pr = df[df['Country Name'] == country_name]

    if (len(df_pr) == 57):
        dfs.append(df_pr)

df_pr = pd.concat(dfs, axis = 0)

# %%
df_pr
# Out:
#                  Country Name Country Code  Year         Value    GDP
# 49     Caribbean small states          CSS  1960  2.004785e+09   0.00
# 50     Caribbean small states          CSS  1961  2.169733e+09   8.23
# 51     Caribbean small states          CSS  1962  2.289495e+09   5.52
# 52     Caribbean small states          CSS  1963  2.431592e+09   6.21
# 53     Caribbean small states          CSS  1964  2.626896e+09   8.03
# ...                       ...          ...   ...           ...    ...
# 11502                Zimbabwe          ZWE  2012  1.424249e+10  17.72
# 11503                Zimbabwe          ZWE  2013  1.545177e+10   8.49
# 11504                Zimbabwe          ZWE  2014  1.589105e+10   2.84
# 11505                Zimbabwe          ZWE  2015  1.630467e+10   2.60
# 11506                Zimbabwe          ZWE  2016  1.661996e+10   1.93
#
# [6840 rows x 5 columns]

# %%
fig = px.line(df_pr, x = 'Year', y = 'GDP', title = 'GDP Growth', color = 'Country Name')

pyo.plot(fig, filename = 'GDP Growth.html', auto_open = True)
# Out:
# 'GDP Growth.html'
